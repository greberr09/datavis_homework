# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# This study was requested by Pymaceuticals, Inc., from one of its senior data scientists.  The study examined a number of metrics to try to determine the relative efficacy of ten drug regimens that are intended to treat a very common form of skin cancer.  The purpose of this study was to compare results from pPymaceuticals’ drug, Capomulin, with the nine other treatment regimens.
#
# The study began with 249 mice and ran for 45 days.  Weights of tumors were observed and measured at intervals throughout the study.  Some mice did not survive for the 45 days.
#
# The executives at Pymaceuticals requested certain tables and figures for a technical report on the clinical study, and have also asked for a top-level summary of the study results.
#
# The analysis included examing mean, median, variance, standard deviation, and standard err for the tumor sizes of mice being treated with each of the ten drug regimens.  The analysis also includeed bar, line, pie, and scatter plots to compare number of observations per drug regimen, the number of male and female mice, tumor size over time for an individual mouse, and tumor size to mouse weight.
#
# All of the plots are included in this Jupyter notebook.

# %% [markdown]
# #### Observations

# %% [markdown]
# During data cleaning, data on one mouse was dropped before the analysis, because duplicate timepoint observations on that mouse made the results suspect.
#
# The study sample of 248 mice was approximately evenly divided between male and female mice, and amonog the ten different regimens under observation.
#
# Two of the drug regimens stand out clearly over the others as extending mouse life.  These are Capomulin, the drug manufactured by the company conducting the study, and Ramicane.  As can be seen in the bar charts, these two drugs produce approximately the same increase in the number of observations per mouse, with many mice in that study surviving to be observed at 45 days.
#
# The other drug regimens all produce approximately 50 fewer observations, on average, with one exception, Propiva, that produces notably fewer observations by at least twenty on average than the
# other, less-successful drug regimens.   While two of the others, on this data, have a slightly larger number of observations per mouse, the differnences here are quite small.  Given the small sample size, however, the differnces might be much more noticeable in a much larger sample.
#
# There is a strong correlation between mouse weight and tumor volume, with Pearson's r at .84.  This can be seen in the scatter plot comparing mouse weight and average tumor volume.
#
# There also appears to be a strong correlation between reduction in tumor size and an increased number of observations (and thus longer mouse life).  The averge tumor sizes for both Capomulin and Ramicane were around 40 mm3, whereas the average tumor sizes in all of the other drug regmins ranged from approximately 52 to 54 mm3.
#
# The correlation is not very strong among the eight other drug regimens.  Mice given Propiva, which had notably the smallest number of observations, and accordingly the shortest survival times, had the smallest average tumor sizes of any of the eight drugs below the top two.  It may be that the differences in tumor weights for this group are too small to reach have any effect, because all of mice in the eight regimens had tumors that were very similar in size, differing on on average by less than 3 mm3.  The results could suggest that there is a cutoff in size in order to extend life expectancy, and all tumors over that cutoff mass will lead to death fairly rapidly.  This data does not indicate where between roughly 44 and 55 mm3 that cutoff might lie.

# %% [markdown]
# #### Take Aways and Next Steps

# %% [markdown]
# The test data size of 248 mice is quite a small sample, and divided between the ten different drug regimens under study, with a study period of 45 days, may be an inadequate representation of the effectiveness of any of these drug regimens.  Each mouse's individual responses are playing too large a role in the overall results.
#
# Nonetheless, in this small study, several metrics are very notable as preliminarily suggestiong that the drug the study sponsor is manufacturing shows promise in extening mouse life.  The sponsor should also note that a second drug regimen appears to be approximately equally sucessful in extending life.  Because the cancer drug market is vast, this should not discourage Pymaceuticals from continuing to pursue development of its drug regimen.
#
# None of the requested charts or metrics show whether there was a difference between tumor size or number of observations, e.g., more days of life, between male and female mice.  While any such difference might not carry over into humans, it would be something worth investigating.  If there is a difference in results between females and males, that could guide future studies, and, eventually,
# if the drug regimen is successful, how the drug is prescribed and marketed.
#
# Additinally, while the mice differed significantly in age (by more than one year, which is quite long in terms of mouse longevity), the analysis to date did not examine whether age may play a role in the observed outomes.  To some extent, the observations of mouse weight may be correlated with age, but so far that has not been established from the current analysis.  The existing data would allow such a comparison.
#
# Because of the large variances and standard deviations seen in tumor size in all of the drug regimens, further studies should be conducted with much larger sample sizes.  Individual idiosyncratic responses may be responsible for variances of 20 mm3, with an average tumor size of 40 mm3.  These differences of almost half of the tumor size among different mice may reflect a successful drug regimen, but this data is too preliminary and the reasons for the results too unclear to determine why the average tumor size appears to have shrunk for some drug regimens.

# %%
# Dependencies and Setup

import string
from pathlib import Path
import random

import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import scipy.stats as st

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame

raw_combined_results = pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID", "Mouse ID"])

# Display the data table for preview

raw_combined_results.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint
# 0     k403     Ramicane  Male          21          16          0  \
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
# Per Stack Overflow, use shape() rather than len() to handle
# null or NAN values that len does not count.

num_mice = (raw_combined_results["Mouse ID"].unique()).shape[0]

num_mice
# Out:
# 249

# %%
all_mice_observations = len(raw_combined_results)

all_mice_observations
# Out:
# 1893

# %%
# The data should be uniquely identified by Mouse ID and Timepoint

# Getting the duplicates methods and dropping the duplicates are based on a combination of 
# information in chatGPT and w3chools.com/python, and the python documentation.

# first identify duplicate rows based on Mouse ID and Timepoint

duplicate_time_rows = raw_combined_results.duplicated(subset=["Mouse ID", "Timepoint"], keep = False)
 

# subset the dataframe to show only the duplicate rows of mouse id/time pairs

duplicates_df = raw_combined_results[duplicate_time_rows]

duplicates_df.head(15)
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint
# 908     g989     Propriva  Female          21          26          0  \
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Get the duplicate mouse ID from the above duplicate pairs

duplicate_mouse  = duplicates_df["Mouse ID"].unique()

duplicate_mouse_id = duplicate_mouse[0]

duplicate_mouse_id
# Out:
# 'g989'

# %%
# Optional:  Display all rows for the duplicate mouse ID

duplicate_rows = raw_combined_results[(raw_combined_results["Mouse ID"] == duplicate_mouse_id)]

duplicate_rows
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint
# 908     g989     Propriva  Female          21          26          0  \
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# Remove the duplicates from the combined results
# Don't keep the first instance of time points for the mouse, just drop all data for that mouse

cleaned_mice = raw_combined_results[(raw_combined_results["Mouse ID"] != duplicate_mouse_id)]

# save output of combined results if desired.  This could be enhanced by
# accepting input as to whether to write the file or not, but that would 
# precluse using "run all" by graders and is outside scope, so hard-coded
# variable was used instead.  The write function will not work if the
# output directory does not exist.  It will create the file if the file
# does not exist, and otherwise will overwrite the file.   This was run wihh
# save on during testing.

save_combined_results = "N"

if save_combined_results == "Y":
    combined_results_path = "output/cleaned_mice.csv"
    cleaned_mice.to_csv(combined_results_path)

cleaned_mice.tail(10)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint
# 1883     z969     Naftisol  Male           9          30          0  \
# 1884     z969     Naftisol  Male           9          30          5
# 1885     z969     Naftisol  Male           9          30         10
# 1886     z969     Naftisol  Male           9          30         15
# 1887     z969     Naftisol  Male           9          30         20
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1883           45.000000                 0
# 1884           49.332999                 0
# 1885           52.656081                 1
# 1886           54.713005                 2
# 1887           57.898778                 2
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4

# %%
# keep a list of clean mouse ids to be used for getting a single random mouse in a later step

clean_mice_ids = cleaned_mice["Mouse ID"].unique()


# Check the overall number of mice remaining in the clean DataFrame

# This could also be done by checking len of clean_mice_ids,
# which would be faster and use less resources if the dataset
# were large, but using shape per Stack Overflow on len with
# null values or NaNs.  Here either way is fast.

num_clean_mice = (cleaned_mice["Mouse ID"].unique()).shape[0]

num_clean_mice
# Out:
# 248

# %% [markdown]
# # Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame

# start with the list of regimens

regimens = []
regimens = cleaned_mice["Drug Regimen"].unique()

#  Sort alphtabetically to match the group bys

regimens.sort()

regimens
# Out:
# array(['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol',
#        'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'],
#       dtype=object)

# %%
# create the base DataFrame

regimens_summary_df = pd.DataFrame({"Drug Regimen" : regimens})

# set the index and reorder for appending the additional group by columns

regimens_summary_df.set_index("Drug Regimen", drop=True, inplace=True)

regimens_summary_df.sort_index(ascending=True, inplace=True)

# %%
# get a list of column names
col_names=cleaned_mice.columns

col_names
# Out:
# Index(['Mouse ID', 'Drug Regimen', 'Sex', 'Age_months', 'Weight (g)',
#        'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites'],
#       dtype='object')

# %%
# Group the mice by drug regimen to use in the statistics calculations

grouped_mice_df = cleaned_mice.groupby(["Drug Regimen"])

grouped_mice_df.head(10)
# Out:
#     Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint
# 0       k403     Ramicane  Male          21          16          0  \
# 1       k403     Ramicane  Male          21          16          5
# 2       k403     Ramicane  Male          21          16         10
# 3       k403     Ramicane  Male          21          16         15
# 4       k403     Ramicane  Male          21          16         20
# ..       ...          ...   ...         ...         ...        ...
# 692     c580     Ketapril  Male          22          25         10
# 693     c580     Ketapril  Male          22          25         15
# 694     c580     Ketapril  Male          22          25         20
# 695     c580     Ketapril  Male          22          25         25
# 696     c580     Ketapril  Male          22          25         30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             45.000000                 0
# 1             38.825898                 0
# 2             35.014271                 1
# 3             34.223992                 1
# 4             32.997729                 1
# ..                  ...               ...
# 692           47.570174                 1
# 693           51.991708                 1
# 694           55.575322                 2
# 695           56.289062                 2
# 696           58.046569                 3
#
# [100 rows x 8 columns]

# %%
# Individually for each regimen, calculate the mean,
# median, variance, and standard deviation 
# of tumor volumes per regimen.
# Calculate the SEM of the standard deviation. 
# Append all new lists to the summary DataFrame


# Collect results for all regions
# Using numpy mean and median rather than Python native because calculation in C is faster

# arrays to hold output from all of the regions
means = []
medians =  []
variances = []
stds = []
stderrs = []
sems= []

# calculate the statistics for each region and append to lists
for regimen in regimens:
    
    regimen_vols = []
    regimen_mean = 0
    regimen_median = 0
    regimen_variance = 0
    regimen_std = 0
    regimen_stderr = 0
    
    regimen_df = pd.DataFrame(cleaned_mice.loc[cleaned_mice["Drug Regimen"] == regimen, :])
    regimen_vols = regimen_df["Tumor Volume (mm3)"]
    
    regimen_mean = np.mean(regimen_vols)
    regimen_median = np.median(regimen_vols)
    
    # np.std and np.var calculate the standard deviation and variance for 
    # the entire population,using N.  Our data is for the entire population, 
    # so this would be the correct way to do it.  The Python "describe()" method  
    # caculates for a sample of the population, using N-1, as do the DataFrame
    # "var" and "sem" methods.  To make the results match, use
    # one degree of freedom (ddoff = 1), in numpy.  The requirement of the 
    # assignment is to match, even though the instructions say that we have 
    # all of the data used in the study.  The study data, however, could be 
    # viewed as a sample of the entire population of mice with tumors.
    
    regimen_variance = np.var(regimen_vols, ddof=1)
    regimen_std = np.std(regimen_vols, ddof=1)
    
    # The default value of sciypy sem() is ddof = 1.
    # This is different than the default for other packages
    # such as DataFrame sem() method, so by using
    # the defaults here the results will match.
    
    regimen_stderr = st.sem(regimen_vols)
    
    means.append(regimen_mean)
    medians.append(regimen_median)
    variances.append(regimen_variance)
    stds.append(regimen_std)
    sems.append(regimen_stderr)

# add the results for all regimen to the summary DataFrame

regimens_summary_df["Mean Tumor Vol"] = means
regimens_summary_df["Median Tumor Vol"] = medians
regimens_summary_df["Variance"] = variances
regimens_summary_df["STD"] = stds
regimens_summary_df["SEM"] = sems

# %% [markdown]
# ## Display the summary statistics by drug regimen

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

regimens_summary_df
# Out:
#               Mean Tumor Vol  Median Tumor Vol   Variance       STD       SEM
# Drug Regimen
# Capomulin          40.675741         41.557809  24.947764  4.994774  0.329346
# Ceftamin           52.591172         51.776157  39.290177  6.268188  0.469821
# Infubinol          52.884795         51.820584  43.128684  6.567243  0.492236
# Ketapril           55.235638         53.698743  68.553577  8.279709  0.603860
# Naftisol           54.331565         52.509285  66.173479  8.134708  0.596466
# Placebo            54.033581         52.288934  61.168083  7.821003  0.581331
# Propriva           52.320930         50.446266  43.852013  6.622085  0.544332
# Ramicane           40.216745         40.673236  23.486704  4.846308  0.320955
# Stelasyn           54.233149         52.431737  59.450562  7.710419  0.573111
# Zoniferol          53.236507         51.818479  48.533355  6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

(grouped_mice_df["Tumor Volume (mm3)"]).agg(['mean', 'median', 'var', 'std', 'sem'])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

#------------------------------------------------------------
# first get the totals of the mouse/timepoin pairs per region
# this will be used in both Pandas and pyplot charts

total_rows = grouped_mice_df["Tumor Volume (mm3)"].count()

# order the results so that the regimen with the longest-living mice appear first

total_rows.sort_values(inplace = True, ascending=False)

ordered_regimens = total_rows.index

#------------------------------------------------------------


# set the locations for the ticks per region

x_axis = np.arange(len(ordered_regimens))

# create the bar plot

fig = total_rows.plot.bar(color="blue", figsize=(8,6),
                                   title="Number of Mouse/Timepoints Observations Per Regimen",
                                   xlabel= "Drug Regimen",
                                   ylabel="Mouse/Timepoint Observations",
                                   alpha=0.75 )
# set the size
fig.title.set_size(14)

# display
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen7 using pyplot

# This matplotlib chart uses results calculated in order to make the Pandas chart

# The figsize has to be set first before the plot call 
plt.figure(figsize=(8, 6))

# create the bar plot, set the size of the bars, dim color tone slightly

fig = plt.bar(x_axis, total_rows, facecolor="blue", alpha=0.75, align="center", width=.5)  

# Configure the appearance of the chart

plt.title("Number of Mouse/Timepoints Observations Per Regimen", fontdict={'fontsize': 14})
plt.title.loc=('center')
    

# setup the ticks for the regions

tick_locations = []

tick_locations = range(1, len(ordered_regimens)+1)
  
tick_names = ['Capomulin', 'Ramicane', 'Ketapril', 'Naftisol', 'Zoniferol', 'Placebo',
       'Stelasyn', 'Ceftamin', 'Infubinol', 'Propriva']

  
# set the lables for the axes
plt.xlabel("Drug Regimen")
plt.ylabel("Mouse/Timepoint Observations")
    
# display
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# ------ first get totals for female and male mice  ------

female_mice_df = pd.DataFrame(cleaned_mice.loc[cleaned_mice["Sex"] == 'Female', :])
male_mice_df = pd.DataFrame(cleaned_mice.loc[cleaned_mice["Sex"] == 'Male', :])

female_mice = female_mice_df["Mouse ID"].unique()
male_mice = male_mice_df["Mouse ID"].unique()

num_female_mice = len(female_mice)
num_male_mice = len(male_mice)

genders = ["Female", "Male"]
gender_counts = [num_female_mice, num_male_mice]

print("female: " + str(num_female_mice))
print("male: " + str(num_male_mice))
# Out:
# female: 123
# male: 125

# %%
#-------------- -create the pie chart with Pandas-------------------

# create the DataFrame
mice_by_gender = pd.DataFrame({'Gender': genders,
                               'Number': gender_counts
                              })

 
# Set up formatting
plot_colors = ["lightcoral", "lightskyblue"]
explodes = [0, 0.05]

# create the chart


fig = mice_by_gender.plot.pie(y="Number", legend=False, figsize=(7, 7),
                               labels=["Female", "Male"],
                               colors=plot_colors,
                               title="Numbers of Female and Male Mice",
                               autopct="%1.1f%%", 
                               shadow=True, 
                               startangle=90,
                               explode = explodes
                             )

# configure the chart

fig.set_ylabel(None)

fig.title.set_size(14)
fig.set_aspect("equal")


# display
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot.

# This chart uses data created for the Pandas chart, so only have to chart the data here

# The figsize has to be set first before the plot call 
plt.figure(figsize=(8, 6))

# create the chart

plt.pie(gender_counts, explode=explodes, labels=genders, colors=plot_colors,
        autopct="%1.1f%%", shadow=True, startangle=90)

# Configure the appearance of the chart

plt.title("Numbers of Female and Male Mice", fontdict={'fontsize': 14})
plt.title.loc=('center')
plt.axis("equal")

# display
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

grouped_mice = cleaned_mice.groupby(["Mouse ID"])

max_timepoints_df = grouped_mice["Timepoint"].max()
max_timepoints_df=max_timepoints_df.reset_index()

# merge with original cleaned mice to get volume for that last timepoint

max_mice_df = max_timepoints_df.merge(cleaned_mice, how="left", on=["Mouse ID", "Timepoint"])

max_mice_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)
# 0       a203         45    Infubinol  Female          20          23  \
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# 2             70.717621                 4
# 3             62.999356                 3
# 4             63.440686                 1
# ..                  ...               ...
# 243           48.710661                 0
# 244           30.638696                 0
# 245           62.754451                 3
# 246           65.741070                 3
# 247           73.867845                 4
#
# [248 rows x 8 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)

treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)

tot_treatment_vols = []
outlier_results = ""

# Loop through each drug in the treatment list, locating the rows in the merged DataFrame that correspond to each treatment. Append the resulting final tumor volumes for each drug to the empty list.

# get the max tumor vol for each treatment and append to total olume list

for treatment in treatments:
    
    outlier_results += (f"For drug regiment {treatment}:\n\n")
    
    treatment_vols_df = pd.DataFrame(max_mice_df.loc[max_mice_df["Drug Regimen"] == treatment, :])
        
    # get all tumor vol rows for this treatment
    
    single_treatment_vols_df = treatment_vols_df["Tumor Volume (mm3)"]
    
    # add the values from this treatment regimen to the totals array
    tot_treatment_vols.append((single_treatment_vols_df.values))
    
    #--------------------------------------------
    # Determine outliers by using the upper and lower bounds .
    #---------------------------------------------

    quart1 = single_treatment_vols_df.describe().iloc[4]
    quart3 = single_treatment_vols_df.describe().iloc[6]
    
    # Calculate the IQR and quantitatively determine if there are any 
    # potential outliers
    
    IQR = quart3 -quart1
    
    outlier_below = quart1 - (1.5*IQR)
    outlier_above = quart3 + (1.5 * IQR)
    
    outlier_results += (f"The first quartile is: {quart1:2.4f}\n")
    outlier_results += (f"The third quartile is: {quart3:2.4f}\n")
    outlier_results += (f"The IQR is: {IQR:2.4f}\n")
    outlier_results += (f"Values below {outlier_below:2.4f} may be outliers\n")
    outlier_results += (f"Values above {outlier_above:2.4f} may be outliers\n")
    outlier_results += (f"\n\n")


# print results for all treatments
print(outlier_results)
# Out:
# For drug regiment Capomulin:
#
# The first quartile is: 32.3774
# The third quartile is: 40.1592
# The IQR is: 7.7819
# Values below 20.7046 may be outliers
# Values above 51.8320 may be outliers
#
#
# For drug regiment Ramicane:
#
# The first quartile is: 31.5605
# The third quartile is: 40.6590
# The IQR is: 9.0985
# Values below 17.9127 may be outliers
# Values above 54.3068 may be outliers
#
#
# For drug regiment Infubinol:
#
# The first quartile is: 54.0486
# The third quartile is: 65.5257
# The IQR is: 11.4771
# Values below 36.8329 may be outliers
# Values above 82.7414 may be outliers
#
#
# For drug regiment Ceftamin:
#
# The first quartile is: 48.7221
# The third quartile is: 64.2998
# The IQR is: 15.5778
# Values below 25.3554 may be outliers
# Values above 87.6665 may be outliers

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# setoutlier properties

box_flierprops = {'marker': 'o', 'markerfacecolor': 'red', 'markeredgecolor': 'red', 'markersize': 8}

# Create box plot
plt.boxplot(tot_treatment_vols, showmeans=True, labels=treatments, flierprops=box_flierprops)
plt.grid()

# configure the plot

treatment_title = "Tumor Volumes for Selected Treatment Regimens"

plt.xlabel('Drug Regimen')
plt.ylabel('Tumor Vol (mm3)')
plt.title(treatment_title, fontdict={'fontsize': 13})
plt.figsize=(8,6)

            
#display           
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# Coding was done first with the specific mouse hardcoded below.  The random
# mouse selection code was then added and testing was done on that as well.
# To get predicatable results for the same mouse each time, the random selection can be
# set to "N" and the hard-wired mouse ID used.  An enhancement would be to allow user input 
# on whether to use the random generation or not, but that might preclude a tester using 
# "run all" on the kernel, and is outside the scope, so it was not added.   Sample mouse
# x401 has particularly dramatic results in terms of tumor shrinkage over time.

use_random = "Y"
sample_mouse_id = 'x401'
sample_drug_regimen = 'Capomulin'

# get all mice for this regimen, which will also be used in a later step
regimen_mice = (cleaned_mice.loc[cleaned_mice["Drug Regimen"] == sample_drug_regimen, :])
num_regimen_mice = len(regimen_mice)

# get a random mouse from this regimen.  Because randint is inclusive on lower bound and inclusive
# on upper bound, don't need to subtract 1 from the length to account for zero-indexing

if use_random == "Y":
    idx = np.random.randint(0, num_regimen_mice)
    sample_mouse_id = regimen_mice.iloc[idx, 0]

sample_mouse_id
# Out:
# 'j119'

# %%
# get all data for this mouse

sample_mouse_timepoints = (cleaned_mice.loc[cleaned_mice["Mouse ID"] == sample_mouse_id, :])

sample_mouse_timepoints
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint
# 328     j119    Capomulin  Female           7          23          0  \
# 329     j119    Capomulin  Female           7          23          5
# 330     j119    Capomulin  Female           7          23         10
# 331     j119    Capomulin  Female           7          23         15
# 332     j119    Capomulin  Female           7          23         20
# 333     j119    Capomulin  Female           7          23         25
# 334     j119    Capomulin  Female           7          23         30
# 335     j119    Capomulin  Female           7          23         35
# 336     j119    Capomulin  Female           7          23         40
# 337     j119    Capomulin  Female           7          23         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 328           45.000000                 0
# 329           45.838998                 0
# 330           46.425366                 0
# 331           47.322984                 0
# 332           48.158209                 1
# 333           42.417166                 1
# 334           43.013681                 1
# 335           43.765705                 1
# 336           44.585090                 1
# 337           38.125164                 1

# %%
# get the tumor volumes and timepoints for this mouse
# and append to sample mouse DataFrame

# Get just the raw values for use in the line plot
sample_vol_results = sample_mouse_timepoints["Tumor Volume (mm3)"]
sample_vols = sample_vol_results.to_numpy()

sample_timepoints_results = sample_mouse_timepoints["Timepoint"]
sample_timepoints=sample_timepoints_results.to_numpy()

sample_mouse_vol_timepoints = pd.DataFrame({'Timepoint' : sample_timepoints,
                               'Tumor Vol' : sample_vols
                              })

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

sample_title = (f"Tumor Volumes Over Time for Mouse {sample_mouse_id} Treated With {sample_drug_regimen}")
sample_color=["green"]

# create the line plot

# Using plot() with kind="line" produces different results with respect to the
# ticklabels and their relationship to the line than does using plot.line.
# This was suggested by chatGPT if manually labeling the ticks and
# their positions produces line out of proportion results that are also
# mentinoed in Stack Overflow multiple times as Pandas line plot can
# produced odd results and for that type of chart better to use mathplotlib

fig = sample_mouse_vol_timepoints.plot(kind="line", y="Tumor Vol", x="Timepoint",
                                    color=sample_color, figsize=(8,6),
                                    title=sample_title,
                                    xlabel= "Time Points (Days)",
                                    ylabel="Tumor Volume (mm3)",
                                    legend=False,      
                                    alpha=0.75 )

                
# display
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %% [markdown]
# 1.  Calculate the correlation coefficient and linear regression model between mouse weight and average observed tumor volume for the entire Capomulin treatment regimen.
#
# 2.  Plot the linear regression model on top of the previous scatter plot.

# %% [markdown]
# ### Correlation

# %%
# get average tumor volumes to compare to mouse weights for the selected regimen

regimen_mice_grouped = (cleaned_mice.loc[cleaned_mice["Drug Regimen"] == sample_drug_regimen, :]).groupby(["Mouse ID"])


regimen_avg_vols=regimen_mice_grouped["Tumor Volume (mm3)"].mean()
regimen_avg_weights=regimen_mice_grouped["Weight (g)"].mean()


# create the dataframe to hold the mice weights and tumor volumes

regimen_mouse_vol_weights = pd.DataFrame({'Mouse Weight' : regimen_avg_weights,
                                       'Tumor Vol' : regimen_avg_vols
                              })

# %%
# Generate a scatter plot of mouse weight vs. average tumor volume for the entire Capomulin regimen

# setup formatting

regimen_title = (f"Mouse Weight vs. Average Tumor Volume for the {sample_drug_regimen} Regimen")

regimen_color="blue"

x_axis = np.arange(len(regimen_mouse_weights))


# create the scatter plot

fig = regimen_mouse_vol_weights.plot.scatter(x="Mouse Weight",
                                             y="Tumor Vol",
                                             s=15,
                                             c=regimen_color,
                                             title=regimen_title,
                                             figsize=(8,6),
                                             xlabel= "Mouse Weight (g)",
                                             ylabel="Tumor Volume (mm3)"
                                            )

# display
plt.show()

# %%
# Calculate the correlation coefficient between mouse weight and average tumor volume

weights=regimen_mouse_vol_weights['Mouse Weight'].to_numpy()
vols=regimen_mouse_vol_weights['Tumor Vol'].to_numpy()

pearsons_r = st.pearsonr(weights, vols)

weight_corr = pearsons_r[0]

print(f"The correlation betweeen mouse weight and tumour volume is {round(weight_corr,2)}.")
# Out:
# The correlation betweeen mouse weight and tumour volume is 0.84.

# %% [markdown]
# ### Linear Regression

# %%
# Perform a linear regression on mouse weogjt versus average tumor volume for study regimen

reg_slope, reg_int, reg_r, reg_p, reg_std_err = st.linregress(weights, vols)

reg_slope
# Out:
# 0.9544396890241049

# %%
# Create equation of line to calculate predicted tumor weight

reg_fit = reg_slope * weights + reg_int

# %%
# Plot the linear model on top of scatter plot 

# using matplotlib this time

plt.scatter(weights, vols, color=regimen_color)

plt.plot(weights, reg_fit,"--", color="lightcoral")

plt.xticks(weights)
plt.xlabel('Mouse Weight (g)')
plt.ylabel('Tumor Vol (mm3)')
plt.title(regimen_title, fontdict={'fontsize': 13})
plt.figsize=(8,6)

# display
plt.show()
